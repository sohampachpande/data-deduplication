# %%
import pandas as pd
import numpy as np

# %%
path = '../../data/error_analysis_RF_fullData.csv'
df = pd.read_csv(path, usecols=['w1', 'w2', 'ground_truth', 'prediction'])

# %%
df['len w1'] = df['w1'].apply(lambda x: len(x))
df['len w2'] = df['w2'].apply(lambda x: len(x))

# %%
df['isCorrect'] = df['ground_truth']==df['prediction']

# %%
statesDic = {
    'alabama': 'al',
    'alaska': 'ak',
    'americansamoa': 'as',
    'arizona': 'az',
    'arkansas': 'ar',
    'california': 'ca',
    'colorado': 'co',
    'connecticut': 'ct',
    'delaware': 'de',
    'districtofcolumbia': 'dc',
    'florida': 'fl',
    'georgia': 'ga',
    'guam': 'gu',
    'hawaii': 'hi',
    'idaho': 'id',
    'illinois': 'il',
    'indiana': 'in',
    'iowa': 'ia',
    'kansas': 'ks',
    'kentucky': 'ky',
    'louisiana': 'la',
    'maine': 'me',
    'maryland': 'md',
    'massachusetts': 'ma',
    'michigan': 'mi',
    'minnesota': 'mn',
    'mississippi': 'ms',
    'missouri': 'mo',
    'montana': 'mt',
    'nebraska': 'ne',
    'nevada': 'nv',
    'newhampshire': 'nh',
    'newjersey': 'nj',
    'newmexico': 'nm',
    'newyork': 'ny',
    'northcarolina': 'nc',
    'northdakota': 'nd',
    'northernmarianaislands': 'mp',
    'ohio': 'oh',
    'oklahoma': 'ok',
    'oregon': 'or',
    'pennsylvania': 'pa',
    'puertorico': 'pr',
    'rhodeisland': 'ri',
    'southcarolina': 'sc',
    'southdakota': 'sd',
    'tennessee': 'tn',
    'texas': 'tx',
    'utah': 'ut',
    'vermont': 'vt',
    'virginislands': 'vi',
    'virginia': 'va',
    'washington': 'wa',
    'westvirginia': 'wv',
    'wisconsin': 'wi',
    'wyoming': 'wy'
}

# %%
def state_abv(x):
    if x in statesDic:
        return statesDic[x] 
    else:
        return x
df['w1'] = df['w1'].apply(lambda x: state_abv("".join(x.split()).lower()))
df['w2'] = df['w2'].apply(lambda x: state_abv("".join(x.split()).lower()))

# %% [markdown]
# ### False Positives

# %%
falsePositives = df[(df['isCorrect']==False) & (df['ground_truth']==0.0)]
falsePositives
# Out:
#                                                w1  \
# 231                            intermission-third
# 248                     exportsofgoodsandservices
# 363          ca-dvbeca-mbca-sbca-sbembemosbsdvosb
# 510                                           120
# 631                                            wv
# 736                                         japan
# 783                               leveldollaropen
# 810                                   chicagopark
# 1456                                     layer2up
# 2476                                  leveldollar
# 2495                                           12
# 2545                    importsofgoodsandservices
# 2735                                 intermission
# 2834                                 intermission
# 3206  ca-dvbeca-mbca-sbca-sbecdvbembemosbsbsbasdb
# 3361                                     layer3up
#
#                                                w2  ground_truth  prediction  \
# 231                                  intermission           0.0         1.0
# 248                     importsofgoodsandservices           0.0         1.0
# 363   ca-dvbeca-mbca-sbca-sbecdvbembemosbsbsbasdb           0.0         1.0
# 510                                            20           0.0         1.0
# 631                                            va           0.0         1.0
# 736                                   afghanistan           0.0         1.0
# 783                                   leveldollar           0.0         1.0
# 810                                       chicago           0.0         1.0
# 1456                                     layer3up           0.0         1.0
# 2476                              leveldollaropen           0.0         1.0
# 2495                                        12,17           0.0         1.0
# 2545                    exportsofgoodsandservices           0.0         1.0
# 2735                           intermission-third           0.0         1.0
# 2834                           intermission-third           0.0         1.0
# 3206         ca-dvbeca-mbca-sbca-sbembemosbsdvosb           0.0         1.0
# 3361                                     layer2up           0.0         1.0
#
#       len w1  len w2  isCorrect
# 231       18      12      False
# 248       29      29      False
# 363       42      51      False
# 510        3       2      False
# 631       13       8      False
# 736        5      11      False
# 783       17      12      False
# 810       12       7      False
# 1456      10      10      False
# 2476      12      17      False
# 2495       2       5      False
# 2545      29      29      False
# 2735      12      18      False
# 2834      12      18      False
# 3206      51      42      False
# 3361      10      10      False

# %% [markdown]
# ### False Negatives

# %%
falseNegatives = df[(df['isCorrect']==False) & (df['ground_truth']==1.0)]
falseNegatives.shape
# Out:
# (90, 7)

# %%
falseNegatives
# Out:
#           w1      w2  ground_truth  prediction  len w1  len w2  isCorrect
# 58      year      yr           1.0         0.0       4       2      False
# 80        ak      ak           1.0         0.0       2       6      False
# 174       ri      ri           1.0         0.0      12       2      False
# 184       nj      nj           1.0         0.0       2      10      False
# 191       ms      ms           1.0         0.0       2      11      False
# ...      ...     ...           ...         ...     ...     ...        ...
# 3160      ms      ms           1.0         0.0       2      11      False
# 3173      mo      mo           1.0         0.0       8       2      False
# 3227  lemnos  limnos           1.0         0.0       6       6      False
# 3273      nc      nc           1.0         0.0       2      14      False
# 3291      nj      nj           1.0         0.0       2      10      False
#
# [90 rows x 7 columns]

# %%
falseNegatives[falseNegatives['w1']!=falseNegatives['w2']].shape
# Out:
# (14, 7)

# %%
falseNegatives.groupby(['len w1']).sum()
# Out:
#         ground_truth  prediction  len w2  isCorrect
# len w1
# 2               46.0         0.0     413          0
# 3                2.0         0.0      15          0
# 4                4.0         0.0       8          0
# 5                7.0         0.0      15          0
# 6                4.0         0.0       8          0
# 7                6.0         0.0      22          0
# 8                4.0         0.0       8          0
# 9                4.0         0.0       8          0
# 10               3.0         0.0      12          0
# 11               1.0         0.0       2          0
# 12               4.0         0.0       8          0
# 13               3.0         0.0       7          0
# 14               4.0         0.0      24          0
# 17               2.0         0.0      34          0
# 18               1.0         0.0      14          0
# 20               2.0         0.0       4          0
# 21               1.0         0.0      26          0
# 26               1.0         0.0      21          0

# %%
falseNegatives.groupby(['len w2']).sum()
# Out:
#         ground_truth  prediction  len w1  isCorrect
# len w2
# 1                2.0         0.0       4          0
# 2               42.0         0.0     363          0
# 3                2.0         0.0      18          0
# 4                1.0         0.0       2          0
# 5                1.0         0.0       2          0
# 6                7.0         0.0      14          0
# 7                7.0         0.0      14          0
# 8                9.0         0.0      26          0
# 9                5.0         0.0      10          0
# 10               5.0         0.0      10          0
# 11               1.0         0.0       2          0
# 12               3.0         0.0      11          0
# 13               3.0         0.0       7          0
# 14               3.0         0.0      22          0
# 15               1.0         0.0       2          0
# 17               2.0         0.0      34          0
# 18               1.0         0.0      14          0
# 21               1.0         0.0      26          0
# 24               2.0         0.0       4          0
# 26               1.0         0.0      21          0

# %% [markdown]
# ### Remove States

# %% [markdown]
# ### Keep Words with len>2

# %%
longWordsDF = df[(df['len w1']>2) & (df['len w2']>2)]

# %%
falseNegativesLong = longWordsDF[(longWordsDF['isCorrect']==False) & (longWordsDF['ground_truth']==1.0)]
falsePositivesLong = longWordsDF[(longWordsDF['isCorrect']==False) & (longWordsDF['ground_truth']==0.0)]

# %%
df[df['ground_truth']==1].shape
# Out:
# (553, 7)

# %%
falseNegativesLong
# Out:
#                               w1                          w2  ground_truth  \
# 49                       kurhaus                kurhaus-saal           1.0
# 745                          prd               prdnationwide           1.0
# 867            associate counsel           associate council           1.0
# 1167  partner, pryor cashman llp       pasricha & patel, llc           1.0
# 1908           associate council           associate counsel           1.0
# 2211               prdnationwide                         prd           1.0
# 2506                       month                         mth           1.0
# 3198              senior partner          sr. staff attorney           1.0
# 3273       pasricha & patel, llc  partner, pryor cashman llp           1.0
# 3337                  well being                    wellness           1.0
# 3372          sr. staff attorney              senior partner           1.0
#
#       prediction  len w1  len w2  isCorrect
# 49           0.0       7      12      False
# 745          0.0       3      13      False
# 867          0.0      17      17      False
# 1167         0.0      26      21      False
# 1908         0.0      17      17      False
# 2211         0.0      13       3      False
# 2506         0.0       5       3      False
# 3198         0.0      14      18      False
# 3273         0.0      21      26      False
# 3337         0.0      10       8      False
# 3372         0.0      18      14      False
